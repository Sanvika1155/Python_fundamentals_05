# %%
students=['sanvika', 'sam', 'adhya', 'munni']
print(students)
# Out:
# ['sanvika', 'sam', 'adhya', 'munni']

# %%
type(students)
# Out:
# list

# %%
students=['sanvika', 'sam', 'adhya', 'munni']
print(students[0])
# Out:
# sanvika

# %%
print(students[0].title())
# Out:
# Sanvika

# %%
students=['sanvika', 'sam', 'adhya', 'munni']
print(students)
# Out:
# ['sanvika', 'sam', 'adhya', 'munni']

# %%
students.append('sitha')
print(students)
# Out:
# ['sanvika', 'sam', 'adhya', 'munni', 'sitha']

# %%
students.insert(3, 'sahasra')
print(students)
# Out:
# ['sanvika', 'sam', 'adhya', 'sahasra', 'munni', 'sitha']

# %%
students[4]='laithra'
print(students)
# Out:
# ['sanvika', 'sam', 'adhya', 'sahasra', 'laithra', 'sitha']

# %%
print(f"keep it up,{students[4].title()}")
# Out:
# keep it up,Laithra

# %%
x=students.pop()
print(students)
# Out:
# ['sanvika', 'sam', 'adhya', 'sahasra', 'laithra']

# %%
print(x)
# Out:
# sitha

# %%
del students[1]
print(students)
# Out:
# ['sanvika', 'adhya', 'sahasra', 'laithra']
