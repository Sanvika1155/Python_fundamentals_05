# %%
firstname="raju"
lastname="yadav"
fullname=f"{firstname}{lastname}"
print(fullname)
# Out:
# rajuyadav

# %%
print(fullname.title())
# Out:
# Rajuyadav

# %%
fullname=f"{firstname}\n{lastname}"
print(fullname)
# Out:
# raju
# yadav

# %%
fullname=f"{firstname}\t{lastname}"
print(fullname)
# Out:
# raju	yadav

# %%
message=f"well done! keep up the good work,{fullname.upper()}"
print(message)
# Out:
# well done! keep up the good work,RAJU	YADAV

# %%
#adding white spaces
print("languages:c,python,java,ai")
# Out:
# languages:c,python,java,ai

# %%
print("languages:c\npython\njava\nai")
# Out:
# languages:c
# python
# java
# ai

# %%
print("languages:\nc\tpython\tjava\tai")
# Out:
# languages:
# c	python	java	ai

# %%
print("languages:\n\tc\n\tpython\n\tjava\n\tai")
# Out:
# languages:
# 	c
# 	python
# 	java
# 	ai

# %%
name="python"
print(name)
# Out:
# python

# %%
name=" python"
print(name.lstrip())
# Out:
# python

# %%
name=" python"
print(name)
# Out:
#  python

# %%
coloring="black "
print(coloring)
# Out:
# black

# %%
coloring="black "
print(coloring.rstrip())
# Out:
# black

# %%
name1=' ardhaya '
print(name1.title())
name1.strip()
# Out:
#  Ardhaya
# 'ardhaya'

# %%
coloring.rstrip()
# Out:
# 'black'

# %%
name.lstrip()
# Out:
# 'python'

# %%
name1.title()
# Out:
# ' Ardhaya '

# %%
name1.upper()
# Out:
# ' ARDHAYA '

# %%
#introduction to numbers
num1=2
num2=5
type(num1)
type(num2)
# Out:
# int

# %%
print(num1+num2)
# Out:
# 7

# %%
a=0.9
type(a)
# Out:
# float

# %%
b=0.001122
type(b)
# Out:
# float
