# %%
print("Hello All! welcome to python class")
# Out:
# Hello All! welcome to python class

# %%
print("hello world")
# Out:
# hello world

# %%
print("good evening")
# Out:
# good evening

# %%
print("welcome back")
# Out:
# welcome back
