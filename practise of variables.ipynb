# %%
firstname="python"
print(firstname)
# Out:
# python

# %%
full name="programming"
print(full name)
# Out:
#   Cell In[2], line 1
#     full name="programming"
#          ^
# SyntaxError: invalid syntax

# %%
1first="language"
print(1first)
# Out:
#   Cell In[3], line 1
#     1first="language"
#     ^
# SyntaxError: invalid decimal literal

# %%
name1="sanvika"
print(name1)
# Out:
# sanvika

# %%
name@="welcome"
print(name@)
# Out:
#   Cell In[5], line 2
#     print(name@)
#                ^
# SyntaxError: invalid syntax

# %%
full_name="programming"
print(full_name)
# Out:
# programming
